# %% [markdown]
# # ANN-Bank Customer Exit Prediction using Keras

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('BankCustomers.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# convert categorical feature into dummy variables

states=pd.get_dummies(X['Geography'],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
#concatenate the remaining dummies columns
X=pd.concat([X,states,gender],axis=1)

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0          1               1        101348.88        0      0     0
# 1          0               1        112542.58        0      1     0
# 2          1               0        113931.57        0      0     0
# 3          0               0         93826.63        0      0     0
# 4          1               1         79084.10        0      1     0

# %%
#drop the columns as it is no longer required

X=X.drop(['Geography','Gender'],axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Building the ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform"))

# Adding the second hidden layer
classifier.add(Dense(activation="relu", units=6, kernel_initializer="uniform"))

# Adding the output layer
classifier.add(Dense(activation="sigmoid", units=1, kernel_initializer="uniform"))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 846us/step - loss: 0.4880 - accuracy: 0.7959
# Epoch 2/100
# 800/800 [==============================] - 1s 985us/step - loss: 0.4291 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 1s 987us/step - loss: 0.4244 - accuracy: 0.79600s - l
# Epoch 4/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4204 - accuracy: 0.8069
# Epoch 5/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4180 - accuracy: 0.8249
# Epoch 6/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4157 - accuracy: 0.8271
# Epoch 7/100
# 800/800 [==============================] - 1s 942us/step - loss: 0.4140 - accuracy: 0.8315
# Epoch 8/100
# 800/800 [==============================] - 1s 853us/step - loss: 0.4125 - accuracy: 0.8310
# Epoch 9/100
# 800/800 [==============================] - 1s 875us/step - loss: 0.4114 - accuracy: 0.8330
# Epoch 10/100
# 800/800 [==============================] - 1s 839us/step - loss: 0.4102 - accuracy: 0.8326
# Epoch 11/100
# 800/800 [==============================] - 1s 758us/step - loss: 0.4088 - accuracy: 0.8335
# Epoch 12/100
# 800/800 [==============================] - 1s 999us/step - loss: 0.4079 - accuracy: 0.8344
# Epoch 13/100
# 800/800 [==============================] - 1s 820us/step - loss: 0.4075 - accuracy: 0.8349
# Epoch 14/100
# 800/800 [==============================] - 1s 928us/step - loss: 0.4067 - accuracy: 0.8347
# Epoch 15/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4063 - accuracy: 0.8346
# Epoch 16/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4055 - accuracy: 0.8346
# Epoch 17/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4054 - accuracy: 0.8360
# Epoch 18/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4045 - accuracy: 0.8341
# Epoch 19/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4041 - accuracy: 0.8349
# Epoch 20/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4037 - accuracy: 0.8349
# Epoch 21/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4040 - accuracy: 0.8344
# Epoch 22/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4035 - accuracy: 0.8359
# Epoch 23/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4031 - accuracy: 0.8341
# Epoch 24/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4026 - accuracy: 0.8351
# Epoch 25/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4026 - accuracy: 0.8351:
# Epoch 26/100
# 800/800 [==============================] - 1s 934us/step - loss: 0.4027 - accuracy: 0.8360
# Epoch 27/100
# 800/800 [==============================] - 1s 969us/step - loss: 0.4023 - accuracy: 0.8356
# Epoch 28/100
# 800/800 [==============================] - 1s 913us/step - loss: 0.4021 - accuracy: 0.8364
# Epoch 29/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4021 - accuracy: 0.8336
# Epoch 30/100
# 800/800 [==============================] - 1s 873us/step - loss: 0.4019 - accuracy: 0.8351
# Epoch 31/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4022 - accuracy: 0.8349
# Epoch 32/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4019 - accuracy: 0.8357
# Epoch 33/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4020 - accuracy: 0.8354
# Epoch 34/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4012 - accuracy: 0.8344
# Epoch 35/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4019 - accuracy: 0.8351
# Epoch 36/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4014 - accuracy: 0.8346
# Epoch 37/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4015 - accuracy: 0.8349
# Epoch 38/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8365
# Epoch 39/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8353
# Epoch 40/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8345
# Epoch 41/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8359
# Epoch 42/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8347
# Epoch 43/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8366
# Epoch 44/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8365
# Epoch 45/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4011 - accuracy: 0.8349
# Epoch 46/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4005 - accuracy: 0.8363
# Epoch 47/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4010 - accuracy: 0.8350
# Epoch 48/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4009 - accuracy: 0.8357
# Epoch 49/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8357
# Epoch 50/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8361
# Epoch 51/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4006 - accuracy: 0.8356
# Epoch 52/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8363
# Epoch 53/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4007 - accuracy: 0.8361
# Epoch 54/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8340
# Epoch 55/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8359
# Epoch 56/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4003 - accuracy: 0.8351
# Epoch 57/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8365
# Epoch 58/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4005 - accuracy: 0.8345
# Epoch 59/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8364
# Epoch 60/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4001 - accuracy: 0.8355: 0s -
# Epoch 61/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4001 - accuracy: 0.8355
# Epoch 62/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4002 - accuracy: 0.8364
# Epoch 63/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8360
# Epoch 64/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8359
# Epoch 65/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4004 - accuracy: 0.8356
# Epoch 66/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4001 - accuracy: 0.8349
# Epoch 67/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3994 - accuracy: 0.8354
# Epoch 68/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4003 - accuracy: 0.8353: 0s
# Epoch 69/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8354
# Epoch 70/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8347
# Epoch 71/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3995 - accuracy: 0.8357
# Epoch 72/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4000 - accuracy: 0.8366
# Epoch 73/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3995 - accuracy: 0.8355
# Epoch 74/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3994 - accuracy: 0.8349
# Epoch 75/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4000 - accuracy: 0.8349
# Epoch 76/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3998 - accuracy: 0.8375
# Epoch 77/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3999 - accuracy: 0.8366
# Epoch 78/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3996 - accuracy: 0.8354
# Epoch 79/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3998 - accuracy: 0.8354
# Epoch 80/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4000 - accuracy: 0.8369
# Epoch 81/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3998 - accuracy: 0.8336
# Epoch 82/100
# 800/800 [==============================] - 1s 994us/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 83/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3996 - accuracy: 0.8347
# Epoch 84/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8369
# Epoch 85/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4000 - accuracy: 0.8364
# Epoch 86/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3995 - accuracy: 0.8359
# Epoch 87/100
# 800/800 [==============================] - 1s 934us/step - loss: 0.3995 - accuracy: 0.8347
# Epoch 88/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8346
# Epoch 89/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 90/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3998 - accuracy: 0.8361
# Epoch 91/100
# 800/800 [==============================] - 1s 972us/step - loss: 0.3998 - accuracy: 0.8356
# Epoch 92/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4000 - accuracy: 0.8369
# Epoch 93/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 94/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 95/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3996 - accuracy: 0.8347
# Epoch 96/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3993 - accuracy: 0.8365: 0s -
# Epoch 97/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3990 - accuracy: 0.8369
# Epoch 98/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 99/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3992 - accuracy: 0.8345
# Epoch 100/100
# 800/800 [==============================] - 1s 959us/step - loss: 0.3994 - accuracy: 0.8354

# %% [markdown]
# ## predictions and evaluating the model

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test, y_pred)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8425

# %%
cm
# Out:
# array([[1539,   56],
#        [ 259,  146]], dtype=int64)
